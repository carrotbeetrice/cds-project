# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import neattext.functions as nfx

# %% [markdown]
# # Load raw dataset

# %%
# Load raw dataset
df = pd.read_csv("data/JCharis/emotion_dataset_raw.csv")

# Check for missing values
df.isnull().sum()
# Out:
# Emotion    0
# Text       0
# dtype: int64

# %% [markdown]
# # Check Emotion value counts

# %%
def plot_emotion_value_counts(data, column='Emotion'):
    plt.figure(figsize=(10, 5))
    ax = sns.countplot(x=column, data=data)
    ax.bar_label(ax.containers[0])
    plt.title("Value counts for Emotions")
    plt.show()

# %%
# Plot raw emotion value counts
plot_emotion_value_counts(df)

# %%
# Remove rows where value counts are less than 2000

emotion_value_counts = df.Emotion.value_counts()
emotions_to_drop = list(emotion_value_counts[emotion_value_counts < 2000].index.values)

df = df.loc[~df.Emotion.isin(emotions_to_drop)]

plot_emotion_value_counts(df)

# %% [markdown]
# # Text Cleaning

# %%
df['Clean_Text'] = df.Text.apply(nfx.remove_stopwords)
df['Clean_Text'] = df['Clean_Text'].apply(nfx.remove_userhandles)
df['Clean_Text'] = df['Clean_Text'].apply(nfx.remove_punctuations)
df.head(20)
# Out:
# <ipython-input-57-46485391ac1d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Clean_Text'] = df.Text.apply(nfx.remove_stopwords)
# <ipython-input-57-46485391ac1d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Clean_Text'] = df['Clean_Text'].apply(nfx.remove_userhandles)
# <ipython-input-57-46485391ac1d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Clean_Text'] = df['Clean_Text'].apply(nfx.remove_punctuations)
#      Emotion                                               Text  \
# 0    neutral                                             Why ?
# 1        joy    Sage Act upgrade on my to do list for tommorow.
# 2    sadness  ON THE WAY TO MY HOMEGIRL BABY FUNERAL!!! MAN ...
# 3        joy   Such an eye ! The true hazel eye-and so brill...
# 4        joy  @Iluvmiasantos ugh babe.. hugggzzz for u .!  b...
# 5       fear  I'm expecting an extremely important phonecall...
# 6    sadness   .Couldnt wait to see them live. If missing th...
# 7   surprise  maken Tip 2: Stop op een moment dat je het hel...
# 8   surprise  En dan krijg je ff een cadeautje van een tweep...
# 9   surprise   @1116am Drummer Boy bij op verzoek van @BiemO...
# 10     anger  The bull tossed the effigy out of their hands ...
# 11   sadness            People hide their behind a #fake smile.
# 12       joy  For once in his life , Leopold must have been ...
# 13      fear  Against the assault of laughter nothing can st...
# 14     anger   With everything , with everybody , with all t...
# 15   sadness  Shakuhachi dress $580,  10-22 mm lens $708 #pa...
# 16  surprise  Haha of course I come home to a different hous...
# 17       joy    I have a feeling i will fail french #fuckfrench
# 18       joy                             Good.Let ' s go now .
# 19  surprise  @JuliaLeader I reeeeeellllyyyyyyy need to tell...
#
#                                            Clean_Text Sentiment
# 0                                                       Neutral
# 1                      Sage Act upgrade list tommorow   Neutral
# 2   WAY HOMEGIRL BABY FUNERAL MAN HATE FUNERALS SH...  Negative
# 3   eye  true hazel eyeand brilliant  Regular feat...  Positive
# 4     ugh babe hugggzzz u  babe naamazed nga ako e...   Neutral
# 5   Im expecting extremely important phonecall min...  Positive
# 6   Couldnt wait live missing NH7 wasnt painful en...  Negative
# 7   maken Tip 2: Stop op een moment dat je het hel...   Neutral
# 8   En dan krijg je ff een cadeautje van een tweep...   Neutral
# 9     Drummer Boy bij op verzoek van      : welke ...   Neutral
# 10              bull tossed effigy hands infuriated    Positive
# 11                            People hide #fake smile  Negative
# 12  life  Leopold truly happy : hopes prayers belo...  Positive
# 13  assault laughter stand ~ Mark Twain #emotional...   Neutral
# 14                                        everybody     Neutral
# 15   Shakuhachi dress $580 1022 mm lens $708 #pain :(  Negative
# 16  Haha course come home different house leave pa...  Positive
# 17                    feeling fail french #fuckfrench  Negative
# 18                                          GoodLet     Neutral
# 19    reeeeeellllyyyyyyy need tell something guess...  Negative

# %% [markdown]
# # Sentiment Analysis

# %%
from textblob import TextBlob

def get_sentiment(text:str)->str:
    blob = TextBlob(text)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        result = 'Positive'
    elif sentiment < 0:
        result = 'Negative'
    else:
        result = 'Neutral'
    return result

# %%
# Add Sentiment column
df["Sentiment"] = df.Text.apply(get_sentiment)
# Out:
# <ipython-input-59-232b20dc2b97>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sentiment"] = df.Text.apply(get_sentiment)

# %%
# Compare Emotion vs Sentiment
grid = sns.catplot(x='Emotion', hue='Sentiment', data=df, kind='count', aspect=1.5)
ax = grid.axes[0, 0]
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %% [markdown]
# # Keyword extraction

# %%
from collections import Counter
from wordcloud import WordCloud

def extract_keywords(text:str, num:int = 50)->dict:
    tokens = [token for token in text.split()]
    most_common_tokens = Counter(tokens).most_common(num)
    return dict(most_common_tokens)

def plot_keywords(keywords_dict: dict, emotion:str):
    keyword_df = pd.DataFrame(keywords_dict.items(), columns=['token', 'count'])
    plt.figure(figsize=(20, 10))
    ax = sns.barplot(x='token', y='count', data=keyword_df)
    ax.bar_label(ax.containers[0])
    plt.xticks(rotation=45)
    plt.title("Keyword counts for " + emotion)
    plt.show()

def plot_wordcloud(docx: str, emotion:str):
    emotion_wordcloud = WordCloud().generate(docx)
    plt.figure(figsize=(20, 10))
    plt.imshow(emotion_wordcloud, interpolation='bilinear')
    plt.title("Word cloud for " + emotion)
    plt.axis('off')
    plt.show()

# %%
# Get list of emotions
emotion_list = df.Emotion.unique().tolist()

# %%
# Extract keywords
emotion_keywords_dict = {}
emotion_docx = {}

for emotion in emotion_list:
    text_list = df[df["Emotion"] == emotion]["Clean_Text"].tolist()
    docx = ' '.join(text_list)
    keywords = extract_keywords(docx)
    emotion_keywords_dict[emotion] = keywords
    emotion_docx[emotion] = docx

# %%
# Plot keyword counts
for emotion in emotion_keywords_dict:
    plot_keywords(emotion_keywords_dict[emotion], emotion)

# %%
# Plot word clouds
for emotion in emotion_docx:
    plot_wordcloud(emotion_docx[emotion], emotion)
